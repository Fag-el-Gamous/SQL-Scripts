# %%
import pandas as pd

df_burials=pd.read_csv("C:/Users/there/Documents/BurialTest.csv")
df_osteology=pd.read_csv("C:/Users/there/Documents/OsteologyTest.csv")
df_burials= df_burials.dropna(axis=1, how='all')
df_burials
# Out:
#             Location  ExcavationYear  BurialNumber HeadDirection  WestToHead  \
# 0    180 N 40 E NE 6            2002             6             W        1.32
# 1    180 N 40 E NE 7            2002             7             W        2.70
# 2    180 N 40 E NE 8            2002             8             W        1.50
# 3    180 N 40 E NE 9            2002             9             W        0.60
# 4   180 N 40 E NE 10            2002            10             W        3.06
# 5   180 N 40 E NE 11            2002            11             W        1.53
# 6   180 N 40 E NE 12            2002            12             E        2.85
# 7   180 N 40 E NE 13            2002            13             W        4.57
# 8   180 N 40 E NE 14            2002            14             W        3.96
# 9   180 N 40 E NE 15            2002            15           NaN        1.94
# 10  180 N 40 E NE 16            2002            16             W        1.23
# ...

# %%
df_combined=pd.merge(df_osteology, df_burials, on=['Location', 'BurialNumber'], how='outer')
df_combined
# Out:
#             Location  BurialNumber BodyExaminationDate  BodyPreservationIndex  \
# 0    180 N 40 E NE 1             1            2/7/2002                    3.0
# 1    180 N 40 E NE 2             2            2/7/2002                    3.0
# 2    180 N 40 E NE 2             2           2/13/2002                    NaN
# 3    180 N 40 E NE 3             3            2/7/2002                    6.0
# 4    180 N 40 E NE 4             4            2/7/2002                    4.0
# 5    180 N 40 E NE 5             5           2/17/2002                    4.0
# 6    180 N 40 E NE 5             5            2/9/2002                    6.0
# 7    180 N 40 E NE 6             6            2/9/2002                    6.0
# 8    180 N 40 E NE 7             7            2/9/2002                    4.0
# 9    180 N 40 E NE 8             8            2/9/2002                    NaN
# 10   180 N 40 E NE 9             9           2/17/2002                    3.0
# ...

# %%
print(df_combined.columns)
# Out:
# Index(['Location', 'BurialNumber', 'BodyExaminationDate',
#        'BodyPreservationIndex', 'HairColor_x', 'HairDescription_x',
#        'RobustCrania', 'SupraorbitalRidgesCrania', 'OrbitEdgeCrania',
#        'ParietalBossingCrania',
#        ...
#        'Unnamed: 166', 'Unnamed: 167', 'Unnamed: 168', 'Unnamed: 169',
#        'Unnamed: 170', 'Unnamed: 171', 'Unnamed: 172', 'Unnamed: 173',
#        'Unnamed: 174', 'Unnamed: 175'],
#       dtype='object', length=211)
